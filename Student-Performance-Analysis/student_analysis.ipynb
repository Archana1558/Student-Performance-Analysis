# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Installed!")
# Out:
# Installed!

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sange\Downloads\archive\Student_Performance.csv")
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  \
# 0                   84.3             yes     <15 min              yes
# 1                   87.8             yes     >60 min               no
# 2                   65.5              no     <15 min               no
# 3                   58.1              no   15-30 min               no
# 4                   61.0             yes   30-60 min              yes
#
#   study_method  math_score  science_score  english_score  overall_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             25000 non-null  int64
#  1   age                    25000 non-null  int64
#  2   gender                 25000 non-null  object
#  3   school_type            25000 non-null  object
#  4   parent_education       25000 non-null  object
#  5   study_hours            25000 non-null  float64
#  6   attendance_percentage  25000 non-null  float64
#  7   internet_access        25000 non-null  object
#  8   travel_time            25000 non-null  object
#  9   extra_activities       25000 non-null  object
#  10  study_method           25000 non-null  object
#  11  math_score             25000 non-null  float64
#  12  science_score          25000 non-null  float64
#  13  english_score          25000 non-null  float64
# ...

# %%
df.describe()
# Out:
#         student_id           age   study_hours  attendance_percentage  \
# count  25000.00000  25000.000000  25000.000000           25000.000000
# mean    7493.04380     16.482760      4.253224              75.084084
# std     4323.56215      1.703895      2.167541              14.373171
# min        1.00000     14.000000      0.500000              50.000000
# 25%     3743.75000     15.000000      2.400000              62.800000
# 50%     7461.50000     16.000000      4.300000              75.100000
# 75%    11252.00000     18.000000      6.100000              87.500000
# max    15000.00000     19.000000      8.000000             100.000000
#
#          math_score  science_score  english_score  overall_score
# count  25000.000000   25000.000000   25000.000000   25000.000000
# mean      63.785944      63.745320      63.681948      64.006172
# std       20.875262      20.970529      20.792693      18.932025
# min        0.000000       0.000000       0.000000      14.500000
# ...

# %%
# !pip install pandas numpy matplotlib

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# school_type              0
# parent_education         0
# study_hours              0
# attendance_percentage    0
# internet_access          0
# travel_time              0
# extra_activities         0
# study_method             0
# math_score               0
# science_score            0
# english_score            0
# overall_score            0
# final_grade              0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# student_id               0.0
# age                      0.0
# gender                   0.0
# school_type              0.0
# parent_education         0.0
# study_hours              0.0
# attendance_percentage    0.0
# internet_access          0.0
# travel_time              0.0
# extra_activities         0.0
# study_method             0.0
# math_score               0.0
# science_score            0.0
# english_score            0.0
# overall_score            0.0
# final_grade              0.0
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 10000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['study_hours'],df['overall_score'])
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.title('Study Hours vs Score')
plt.show()

# %%
df.groupby('attendance_percentage')['overall_score'].mean().plot()
plt.title('Attendance vs Score')
plt.show()

# %%
df.groupby('gender')['overall_score'].mean().plot(kind='bar')
plt.title('Average Score by Gender')
plt.show()

# %%
df.groupby('school_type')['overall_score'].mean().plot(kind='bar')
plt.title('Public vs Private School Performance')
plt.show()

# %%
df.groupby('study_method')['overall_score'].mean().plot(kind='bar')
plt.title('Study Method vs Score')
plt.show()

# %%
import sqlite3
conn=sqlite3.connect('student.db')
df.to_sql('students', conn, if_exists='replace', index=False)
# Out:
# 25000

# %%
query='SELECT AVG(overall_score) FROM students'
pd.read_sql(query,conn)
# Out:
#    AVG(overall_score)
# 0           64.006172

# %%
query = "SELECT * FROM students"
pd.read_sql(query, conn)
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
query="SELECT study_method, AVG(overall_score) FROM students GROUP BY study_method"
pd.read_sql(query, conn)
# Out:
#     study_method  AVG(overall_score)
# 0       coaching           64.368405
# 1    group study           63.249487
# 2          mixed           63.613960
# 3          notes           63.895318
# 4  online videos           64.686905
# 5       textbook           64.238122

# %%
query = """
SELECT 
CASE 
    WHEN attendance_percentage > 75 THEN 'High'
    ELSE 'Low'
END AS attendance_level,
AVG(overall_score)
FROM students
GROUP BY attendance_level;
"""

pd.read_sql(query, conn)
# Out:
#   attendance_level  AVG(overall_score)
# 0             High           68.848497
# 1              Low           59.159196

# %%
query= "SELECT internet_access, AVG(overall_score) FROM students GROUP BY internet_access"
pd.read_sql(query,conn)
# Out:
#   internet_access  AVG(overall_score)
# 0              no           63.774821
# 1             yes           64.047294

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['study_hours']]   
y = df['overall_scores']            

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8159114163150487

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='red')
plt.show()
